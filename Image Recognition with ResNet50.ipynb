# %% [markdown]
# ### Importing all necessary Libraries

# %%
import pandas as pd
import numpy as np

# %%
import tensorflow
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input
from keras.applications.resnet50 import ResNet50, decode_predictions

# %% [markdown]
# ### Pre-Processing Images for ResNet50

# %%
image_path = "C:\\Users\\DELL\\AA\\Dog.jpg"

# %%
# loading the Image and Turning into Array 
img = image.load_img(image_path, target_size=(224, 224))
img = image.img_to_array(img)

# %%
# Expanding the Dimensions
img = np.expand_dims(img, axis=0)

# %%
# Pre-Processing the Image
img = preprocess_input(img)

# %% [markdown]
# ### Visualizing the Image Data

# %%
import matplotlib.pyplot as plt

# %%
data = plt.imread(image_path)
plt.imshow(data)
plt.show()

# %% [markdown]
# ### Using Pre-Trained ResNet50

# %%
model = ResNet50(weights="imagenet")

# %%
pred = model.predict(img)

# %% [markdown]
# ### Decoding the Predictions

# %%
print("Predicted: ", decode_predictions(pred, top=3)[0])
# Out:
# Predicted:  [('n02111889', 'Samoyed', 0.9357807), ('n02114548', 'white_wolf', 0.056335315), ('n02112137', 'chow', 0.0036022277)]
